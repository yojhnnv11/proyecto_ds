# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Carga del dataset
# En esta sección se carga el archivo `Raw Data.csv` para iniciar el análisis exploratorio y diagnóstico de calidad de datos.

# %%
df = pd.read_csv('../Raw_Data.csv')

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
df.tail()
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16714    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
# 16715   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
#
# ...

# %%
df.shape
# Out:
# (16719, 16)

# %% [markdown]
# ## 3. Diagnóstico principal del dataset
# Se utiliza el método `.info()` para identificar el número de registros, columnas, tipos de datos y valores no nulos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# ...

# %% [markdown]
# ## 4. Revisión de valores nulos
# Se identifican las columnas con datos faltantes para evaluar posibles problemas de calidad.

# %%
df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# User_Count         9129
# Critic_Count       8582
# Critic_Score       8582
# Rating             6769
# User_Score         6704
# Developer          6623
# Year_of_Release     269
# Publisher            54
# Name                  2
# Genre                 2
# NA_Sales              0
# Platform              0
# JP_Sales              0
# EU_Sales              0
# Other_Sales           0
# Global_Sales          0
# dtype: int64

# %% [markdown]
# ## 5. Resumen estadístico de variables numéricas
# Se analizan las variables cuantitativas del dataset, como las ventas por región y ventas globales.

# %%
df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %% [markdown]
# ## 6. Resumen estadístico de variables categóricas
# Se examinan las variables tipo texto, como nombre del videojuego, plataforma, género y editorial.

# %%
df.describe(include='object')
# Out:
#                                Name Platform   Genre        Publisher  \
# count                         16717    16719   16717            16665
# unique                        11562       31      12              581
# top     Need for Speed: Most Wanted      PS2  Action  Electronic Arts
# freq                             12     2161    3370             1356
#
#        User_Score Developer Rating
# count       10015     10096   9950
# unique         96      1696      8
# top           tbd   Ubisoft      E
# freq         2425       204   3991

# %% [markdown]
# ## 7. Revisión de registros duplicados
# Se valida si existen registros repetidos que puedan afectar la calidad del análisis.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 8. Estructura de columnas
# Se listan los nombres de las columnas para verificar la organización y comprensión del dataset.

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object

# %% [markdown]
# ## 9. Conclusión del diagnóstico inicial
#
# A partir de la inspección inicial del dataset de videojuegos, se logró identificar la estructura general de los datos, los tipos de variables presentes y algunos posibles problemas de calidad como valores nulos, posibles inconsistencias en columnas categóricas y la necesidad de validar ciertos registros antes de realizar un análisis más profundo.
#
# Este diagnóstico es fundamental como etapa previa al proceso de limpieza, transformación y análisis exploratorio de datos.

# %% [markdown]
# # GA1-240201064-04-AA1-EV06
# # Informe de Diagnóstico de Calidad de Datos – Dataset de Videojuegos
#
# **Aprendiz:** yojhann V
# **Programa:** [Tu programa de formación]
# **Actividad:** Diagnóstico de la Calidad de Datos
# **Dataset analizado:** `Raw_Data.csv`
#
# ---
#
# ## 1. Introducción
#
# El presente informe tiene como objetivo realizar un diagnóstico inicial de calidad de datos sobre un dataset del sector de los videojuegos, utilizando herramientas de análisis en Python, específicamente la librería Pandas, dentro de un entorno Jupyter Notebook.
#
# Este proceso permite identificar la estructura general del conjunto de datos, los tipos de variables presentes, la existencia de valores nulos, posibles inconsistencias y otros aspectos relevantes antes de iniciar un proceso de limpieza o análisis más profundo.
#
# ---
#
# ## 2. Objetivo del análisis
#
# Realizar una inspección inicial del dataset `Raw_Data.csv`, con el fin de evaluar su estado, comprender su estructura y detectar posibles problemas de calidad de datos que puedan afectar el análisis posterior.
#
# ---
#
# ## 3. Carga y exploración inicial del dataset
#
# El dataset fue cargado correctamente en Pandas desde el archivo `Raw_Data.csv`. Posteriormente, se aplicaron funciones básicas de exploración como:
#
# - `.head()`
# - `.tail()`
# - `.shape`
#
# Estas funciones permitieron observar la estructura general del archivo, sus primeros y últimos registros, así como la cantidad de filas y columnas presentes.
#
# A partir de esta revisión, se evidenció que el dataset contiene información relacionada con videojuegos, incluyendo atributos como:
#
# - Nombre del videojuego
# - Plataforma
# - Año de lanzamiento
# - Género
# - Editorial
# - Ventas por región
# - Ventas globales
#
# ---
#
# ## 4. Estructura del dataset
#
# El análisis de la estructura del dataset permitió identificar que se trata de un conjunto de datos tabular, organizado por filas (registros) y columnas (variables).
#
# Cada fila representa un videojuego, mientras que cada columna contiene una característica específica del mismo.
#
# El comando `.shape` permitió conocer el tamaño total del dataset, mientras que `.columns` facilitó la revisión de los nombres de las variables disponibles.
#
# Este tipo de estructura es adecuada para realizar análisis exploratorio, limpieza de datos, generación de estadísticas y visualización de tendencias.
#
# ---
#
# ## 5. Diagnóstico principal del dataset
#
# Para realizar el diagnóstico principal, se utilizó el método `.info()`, el cual permitió obtener información relevante como:
#
# - Número total de registros
# - Número total de columnas
# - Cantidad de valores no nulos por columna
# - Tipos de datos asignados a cada variable
#
# Gracias a este análisis, fue posible identificar que el dataset contiene tanto variables **numéricas** como **categóricas**.
#
# ### Variables numéricas:
# Estas columnas están relacionadas principalmente con cantidades de ventas, por ejemplo:
#
# - Ventas en Norteamérica
# - Ventas en Europa
# - Ventas en Japón
# - Otras ventas
# - Ventas globales
#
# ### Variables categóricas:
# Estas columnas representan información descriptiva del videojuego, por ejemplo:
#
# - Nombre
# - Plataforma
# - Género
# - Editorial
#
# La identificación de estos tipos de variables es importante porque determina qué tipo de análisis y tratamiento se puede aplicar a cada una.
#
# ---
#
# ## 6. Identificación de valores nulos
#
# Uno de los aspectos más importantes dentro del diagnóstico de calidad de datos es la detección de valores faltantes o nulos.
#
# Para ello, se utilizó el método:
#
# ```python id="j4s2af"
# df.isnull().sum()
